# %%
import matplotlib.pyplot as plt
#plt.switch_backend('agg')
import matplotlib.ticker as ticker
import numpy as np
import json

# %%
##note: validation loss, train accuracy, val accuracy calculated ev

# %%
### continued from previous encoder and decoder

# %%
with open("plots/ValidationLoss.json", "r") as fp:
        epoch_loss_plot = json.load(fp)
        
        
plt.plot(range(len(epoch_loss_plot)), epoch_loss_plot, color="blue")
plt.title("Validation Loss")
plt.xlabel("Epoch")
# Out:
# Text(0.5,0,'Epoch')

# %%
with open("plots/TrainingLossEpoch.json", "r") as fp:
        epoch_loss_plot = json.load(fp)
        
        
plt.plot(range(len(epoch_loss_plot)), epoch_loss_plot, color="blue")
plt.title("Training Loss by Epoch")
plt.xlabel("Epoch")
# Out:
# Text(0.5,0,'Epoch')

# %%
with open("plots/TrainingLossIter.json", "r") as fp:
        loss_plot = json.load(fp)

plt.plot(range(len(loss_plot)), loss_plot, color="blue")
plt.title("Training Loss by iteration")
plt.xlabel("Iteration")
# Out:
# Text(0.5,0,'Iteration')

# %%
with open("plots/TrainingAccuracy.json", "r") as fp:
        loss_plot = json.load(fp)

plt.plot(range(len(loss_plot)), loss_plot, color="blue")
plt.title("Training accuracy")
plt.xlabel("Epoch")
# Out:
# Text(0.5,0,'Epoch')

# %%
with open("plots/ValidationAccuracy.json", "r") as fp:
        loss_plot = json.load(fp)

plt.plot(range(len(loss_plot)), loss_plot, color="blue")
plt.title("Validation accuracy")
plt.xlabel("Epoch")
# Out:
# Text(0.5,0,'Epoch')

# %%
##### With training embedding for input goals

# %%
with open("plots/ValidationLoss.json", "r") as fp:
        epoch_loss_plot = json.load(fp)
        
        
plt.plot(range(len(epoch_loss_plot)), epoch_loss_plot, color="blue")
plt.title("Validation Loss")
plt.xlabel("Epoch")

# %%
with open("plots/TrainingLossEpoch.json", "r") as fp:
        epoch_loss_plot = json.load(fp)
        
        
plt.plot(range(len(epoch_loss_plot)), epoch_loss_plot, color="blue")
plt.title("Training Loss by Epoch")
plt.xlabel("Epoch")
# Out:
# Text(0.5,0,'Epoch')

# %%
with open("plots/TrainingLossIter.json", "r") as fp:
        loss_plot = json.load(fp)

plt.plot(range(len(loss_plot)), loss_plot, color="blue")
plt.title("Training Loss by iteration")
plt.xlabel("Iteration")
# Out:
# Text(0.5,0,'Iteration')

# %%
with open("plots/TrainingAccuracy.json", "r") as fp:
        loss_plot = json.load(fp)

plt.plot(range(len(loss_plot)), loss_plot, color="blue")
plt.title("Training accuracy")
plt.xlabel("Epoch")
# Out:
# Text(0.5,0,'Epoch')

# %%
with open("plots/ValidationAccuracy.json", "r") as fp:
        loss_plot = json.load(fp)

plt.plot(range(len(loss_plot)), loss_plot, color="blue")
plt.title("Validation accuracy")
plt.xlabel("Epoch")
# Out:
# Text(0.5,0,'Epoch')
