# %%
import matplotlib.pyplot as plt
#plt.switch_backend('agg')
import matplotlib.ticker as ticker
import numpy as np
import json

# %%
#### with GRU and tanh activation

# %%
with open("plots/NumCorrectOutputs.json", "r") as fp:
        loss_plot = json.load(fp)

plt.plot(range(len(loss_plot)), loss_plot, color="blue")
plt.title("NumCorrectOutputs")
plt.xlabel("Epoch")
# Out:
# Text(0.5,0,'Epoch')

# %%
with open("plots/TotalDifferenceInOutput.json", "r") as fp:
        loss_plot = json.load(fp)

plt.plot(range(len(loss_plot)), loss_plot, color="blue")
plt.title("TotalDifferenceInOutput")
plt.xlabel("Epoch")
# Out:
# Text(0.5,0,'Epoch')

# %%
with open("plots/TrainingLossIter.json", "r") as fp:
        loss_plot = json.load(fp)

plt.plot(range(len(loss_plot)), loss_plot, color="blue")
plt.title("Training Loss by iteration")
plt.xlabel("Iteration")
# Out:
# Text(0.5,0,'Iteration')

# %%
with open("plots/TrainingLossEpoch.json", "r") as fp:
        epoch_loss_plot = json.load(fp)
        
        
plt.plot(range(len(epoch_loss_plot)), epoch_loss_plot, color="blue")
plt.title("Training Loss by Epoch")
plt.xlabel("Epoch")
# Out:
# Text(0.5,0,'Epoch')

# %%
### without GRU, standard RNN

# %%
with open("plots/NumCorrectOutputs.json", "r") as fp:
        loss_plot = json.load(fp)

plt.plot(range(len(loss_plot)), loss_plot, color="blue")
plt.title("NumCorrectOutputs")
plt.xlabel("Epoch")
# Out:
# Text(0.5,0,'Epoch')

# %%
with open("plots/TotalDifferenceInOutput.json", "r") as fp:
        loss_plot = json.load(fp)

plt.plot(range(len(loss_plot)), loss_plot, color="blue")
plt.title("TotalDifferenceInOutput")
plt.xlabel("Epoch")
# Out:
# Text(0.5,0,'Epoch')

# %%
with open("plots/TrainingLossEpoch.json", "r") as fp:
        epoch_loss_plot = json.load(fp)
        
plt.plot(range(len(epoch_loss_plot)), epoch_loss_plot, color="blue")
plt.title("Training Loss by Epoch")
plt.xlabel("Epoch")
# Out:
# Text(0.5,0,'Epoch')

# %%
with open("plots/TrainingLossIter.json", "r") as fp:
        loss_plot = json.load(fp)

plt.plot(range(len(loss_plot)), loss_plot, color="blue")
plt.title("Training Loss by iteration")
plt.xlabel("Iteration")
# Out:
# Text(0.5,0,'Iteration')

# %%
### using GRU

# %%
with open("plots/NumCorrectOutputs.json", "r") as fp:
        loss_plot = json.load(fp)

plt.plot(range(len(loss_plot)), loss_plot, color="blue")
plt.title("NumCorrectOutputs")
plt.xlabel("Epoch")
# Out:
# Text(0.5,0,'Epoch')

# %%
with open("plots/TotalDifferenceInOutput.json", "r") as fp:
        loss_plot = json.load(fp)

plt.plot(range(len(loss_plot)), loss_plot, color="blue")
plt.title("TotalDifferenceInOutput")
plt.xlabel("Epoch")
# Out:
# Text(0.5,0,'Epoch')

# %%
with open("plots/TrainingLossIter.json", "r") as fp:
        loss_plot = json.load(fp)

plt.plot(range(len(loss_plot)), loss_plot, color="blue")
plt.title("Training Loss by iteration")
plt.xlabel("Iteration")
# Out:
# Text(0.5,0,'Iteration')

# %%
with open("plots/TrainingLossEpoch.json", "r") as fp:
        epoch_loss_plot = json.load(fp)
        
        
plt.plot(range(len(epoch_loss_plot)), epoch_loss_plot, color="blue")
plt.title("Training Loss by Epoch")
plt.xlabel("Epoch")
# Out:
# Text(0.5,0,'Epoch')
